# %%
import torch
import os
import tiktoken
import math

from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
from dataclasses import dataclass

# %%
dataset_dir = Path("dataset/harry-potter-books")
os.listdir(dataset_dir)
# Out:
# ['01 Harry Potter and the Sorcerers Stone.txt',
#  '02 Harry Potter and the Chamber of Secrets.txt',
#  '03 Harry Potter and the Prisoner of Azkaban.txt',
#  '04 Harry Potter and the Goblet of Fire.txt',
#  '05 Harry Potter and the Order of the Phoenix.txt',
#  '06 Harry Potter and the Half-Blood Prince.txt',
#  '07 Harry Potter and the Deathly Hallows.txt']

# %%
enc = tiktoken.get_encoding("gpt2")
enc.encode("hello, my name is mr. robot")
# Out:
# [31373, 11, 616, 1438, 318, 285, 81, 13, 9379]

# %%
@dataclass
class GPTConfig:
    block_size: int = 128
    n_embd: int = 64
    n_head: int = 4
    vocab_size: int = 50304
    n_layers: int = 4 # or change to 6 for betterment

# %%
class MHA(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.qkv_mat = nn.Linear(config.n_embd, 3 * config.n_embd)
        self.register_buffer('bias', torch.tril(torch.ones(config.block_size, config.block_size)).view(1, 1, config.block_size, config.block_size))
        self.c_proj = nn.Linear(config.n_embd, config.n_embd)
    
    def forward(self, x):
        B, T, C = x.shape
        qkv = self.qkv_mat(x)
        q, k, v = torch.split(qkv, self.config.n_embd, dim=-1)
        q = q.view(B, T, self.config.n_head, C // self.config.n_head).transpose(1, 2)
        k = k.view(B, T, self.config.n_head, C // self.config.n_head).transpose(1, 2)
        v = v.view(B, T, self.config.n_head, C // self.config.n_head).transpose(1, 2)

        att = (q @ k.transpose(-2, -1)) / math.sqrt(k.shape[-1])
        att = att.masked_fill(self.bias[:, :, :T, :T] == 0, value=float('-inf'))
        att = F.softmax(att, dim=-1)
        y = att @ v

        y = y.transpose(1, 2).view(B, T, C)
        y = self.c_proj(y)
        return y

# %%
class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.linear_1 = nn.Linear(config.n_embd, 2 * config.n_embd)
        self.gelu = nn.GELU(approximate="tanh")
        self.linear_2 = nn.Linear(2 * config.n_embd, config.n_embd)
    
    def forward(self, x):
        x = self.linear_1(x)
        x = self.gelu(x)
        x = self.linear_2(x)
        return x

# %%
class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.mha = MHA(config)
        self.ln_1 = nn.LayerNorm(config.n_embd)
        self.mlp = MLP(config)
        self.ln_2 = nn.LayerNorm(config.n_embd)
    
    def forward(self, x):
        x = x + self.ln_1(self.mha(x))
        x = x + self.ln_2(self.mlp(x))
        return x

# %%
class hpGPT(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.transformer = nn.ModuleDict(dict(
            w_tok_emb = nn.Embedding(config.vocab_size, config.n_embd),
            w_pos_emb = nn.Embedding(config.block_size, config.n_embd),
            blocks = nn.ModuleList([Block(config) for _ in range(config.n_layers)]),
            ln_f = nn.LayerNorm(config.n_embd)
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

    def forward(self, idx, targets=None): # idx : encoded text
        print("finding tok_emb")
        tok_emb = self.transformer.w_tok_emb(idx) # B, T, C
        print("finding pos_emb")
        pos_emb = self.transformer.w_pos_emb(torch.arange(self.config.block_size, device=idx.device))

        print(tok_emb.shape, pos_emb.shape)
        x = tok_emb + pos_emb

        for block in self.transformer.blocks:
            x = block(x)
        x = self.transformer.ln_f(x)
        
        logits = self.lm_head(x)
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.shape[-1]), targets.view(-1))
        
        return logits, loss
    
    def generate(self, start_string: str, num_return_sequences: int, max_length: int, device: torch.device):
        assert max_length <= self.config.block_size
        enc = tiktoken.get_encoding("gpt2")
        tokens = enc.encode(start_string)
        tokens = tokens.unsqueeze(0).repeat(num_return_sequences, 1)
        xgen = tokens.to(device)

        while xgen.shape[1] < max_length:
            with torch.no_grad():
                logits, _ = self(xgen)
                logits = logits[:, -1, :]
                probs = F.softmax(logits, dim=-1)
                top50_values, top50_indices = torch.topk(probs, k=50, dim=-1)
                prob_indices = torch.multinomial(top50_values, num_samples=1)
                attached_tensor = torch.gather(top50_indices, dim=-1, index=prob_indices)
                xgen = torch.cat((xgen, attached_tensor), dim=1)
        
        for row_t in xgen:
            print(enc.decode(row_t.tolist()))

# %%
# ROUGH WORK
# 
# probz = torch.randn(3, 4, 5)
# probz[:, -1, :].shape

# a = torch.arange(15).reshape(3, 1, -1)
# a

# top3_vals, top3_idx = torch.topk(a, k=3)
# top3_vals, top3_idx
# top3_idx.shape

# sample_idx = torch.multinomial(top3_vals.view(top3_vals.shape[0], -1).type(torch.float), num_samples=1)
# sample_idx

# torch.gather(top3_idx.squeeze(1), dim=1, index=sample_idx)

# %% [markdown]
# hpGPT:
# embedding matrix x2
# blocks list
#     blocks:
#         mha + ln
#         mlp + ln
# mlp
# softmax

# %%
# class HPDataset(Dataset):
#     def __init__(self, texts, tokenizer_name="gpt2", max_length=128):
#         self.texts = texts
#         self.tokenizer = tiktoken.get_encoding(tokenizer_name)
#         self.max_length = max_length
    
#     def __len__(self)
#         return len(self.texts)
    
#     def

# %%
def load_tokens(filename):
    with open(filename, "r") as f:
        f_content = f.read()
    
    enc = tiktoken.get_encoding("gpt2")
    tokens = enc.encode(f_content)
    tokens = torch.tensor(tokens, dtype=torch.long)
    return tokens


class HPDataloaderLite:
    def __init__(self, B, T, split):
        self.B = B
        self.T = T
        assert split in {"train", "val"}

        data_root = dataset_dir
        shards = os.listdir(data_root)
        shards = [s for s in shards if split in s]
        shards = sorted(shards)
        shards = [os.path.join(data_root, s) for s in shards]
        self.shards = shards
        assert len(shards) > 0, f"no shards found for split {split}"
        
        self.reset()
    
    def next_batch(self):
        B, T = self.B, self.T
        buf = self.tokens[self.current_position : self.current_position + B*T + 1]
        if len(buf) != B*T + 1:
            self.current_shard = (self.current_shard + 1) % len(self.shards)
            self.tokens = load_tokens(self.shards[self.current_shard])
            self.current_position = 0
            buf = self.tokens[self.current_position : self.current_position + B*T + 1]
            
        x = buf[:-1].view(B, T)
        y = buf[1:].view(B, T)

        print(f"inside dataloader: {x.shape, y.shape}, shapes of x, y")

        self.current_position += B*T

        # if self.current_position == (self.current_parent_batch + 1) * 32 * B * T:
        #     if self.current_shard + 1 == len(self.shards):
        #         self.current_parent_batch = (self.current_parent_batch + 1) % 381
        #     self.current_shard = (self.current_shard + 1) % len(self.shards)
        #     self.tokens = load_tokens(self.shards[self.current_shard])
        #     self.current_position = self.current_parent_batch * 32 * B * T
            
        return x, y

    def reset(self):
        self.current_shard = 0
        self.tokens = load_tokens(self.shards[self.current_shard])
        self.current_position = 0
        self.current_parent_batch = 0

    def reset_from_config(self, current_shard, current_parent_batch):
        self.current_shard = current_shard
        self.current_parent_batch = current_parent_batch
        self.tokens = load_tokens(self.shards[self.current_shard])
        self.current_position = current_parent_batch * 32 * self.B * self.T

# %%
book_list = os.listdir(dataset_dir)
for i in range(7):
    book_list[i] = dataset_dir / book_list[i]


for book in book_list:
    with open(book, 'r') as f:
        f_content = f.read()
    f_content_encoding = enc.encode(f_content)
    print(len(f_content_encoding))
# Out:
# 124336
# 137248
# 175913
# 289032
# 367905
# 269790
# 305068

# %% [markdown]
# batch size = 4096
# B = 8
#
# grad accumulation for grad_accum_steps = 4098 / 8
#
# accumulate and then take average
#
# design a cosine dropping learning rate

# %%
max_lr = 3e-4
min_lr = 0.1 * max_lr
warmup_steps = 16
max_steps = 128

def get_lr(step):
    if step < warmup_steps:
        return min_lr + 0.9 * max_lr * step / warmup_steps
    else:
        coeff = (max_steps - step) / (max_steps - warmup_steps)
        coeff = math.sin(coeff * math.pi / 2)
        return min_lr + coeff * (max_lr - min_lr)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
model = hpGPT(GPTConfig)
model.to(device)
model = torch.compile(model)

# %%
batch_size = 4096 * 2
B = 8 # can increase in case of gpu training
T = GPTConfig.block_size
grad_accum_steps = batch_size //(B*T)

train_loader = HPDataloaderLite(B, T, "train")
val_loader = HPDataloaderLite(B, T, "val")

optimizer = torch.optim.AdamW(params=model.parameters(), lr=3e-4)

iters = []
loss_list = []

for step in range(max_steps):
    val_loss = 0.0
    if step % 8 == 0:
        model.eval()
        with torch.no_grad():
            x, y = val_loader.next_batch()
            x, y = x.to(device), y.to(device)

            print("inside train loop:", {x.shape, y.shape}, "shapes of x, y")

            logits, val_loss = model(x, y)
        print(f"val loss: {val_loss.item():.4f}")
        print()

    model.train()
    loss_accum = 0.0
    optimizer.zero_grad()
    for grad_step in range(grad_accum_steps):
        x, y = train_loader.next_batch()
        x, y = x.to(device), y.to(device)

        logits, loss = model(x, y)
        loss /= grad_accum_steps
        loss_accum += loss.detach()
        loss.backward()
    
    lr = get_lr(step)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
        
    optimizer.step()
    iters.apend(step)
    loss_list.append(loss_accum.cpu().item())

    if step % 4 == 0 or step == max_steps-1:
        print(f"step: {step}, avg_loss: {loss_accum.item():.4f}, lr: {lr:.4e}")
    
    if step % 16 == 0 or step == max_steps-1:
        model.eval()
        model.generate("Wingardium Leviosa!", 3, 50, device)
        print()
        print()
# Out:
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5] failed while attempting to run meta for aten.view.default
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5] Traceback (most recent call last):
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]   File "/home/lurix/code/ml/.venv/lib64/python3.13/site-packages/torch/_subclasses/fake_tensor.py", line 2427, in _dispatch_impl
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]     r = func(*args, **kwargs)
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]   File "/home/lurix/code/ml/.venv/lib64/python3.13/site-packages/torch/_ops.py", line 756, in __call__
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]     return self._op(*args, **kwargs)
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]            ~~~~~~~~^^^^^^^^^^^^^^^^^
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]   File "/home/lurix/code/ml/.venv/lib64/python3.13/site-packages/torch/_refs/__init__.py", line 4671, in view
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]     return _reshape_view_helper(a, *shape, allow_copy=False)
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]   File "/home/lurix/code/ml/.venv/lib64/python3.13/site-packages/torch/_refs/__init__.py", line 3800, in _reshape_view_helper
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5]     raise ValueError(msg)
# E0705 23:39:55.392000 13957 torch/_subclasses/fake_tensor.py:2431] [0/5] ValueError: Cannot view a tensor with shape torch.Size([8, 128, 4, 16]) and strides (8192, 16, 2048, 1) as a tensor with shape (8, 128, 64)!
# torch.Size([8, 128]) torch.Size([8, 128])
# ---------------------------------------------------------------------------
# TorchRuntimeError                         Traceback (most recent call last)
# Cell In[83], line 24
#      20     x, y = x.to(device), y.to(device)
#      22     print(x.shape, y.shape)
# ---> 24     logits, val_loss = model(x, y)
#      25 print(f"val loss: {val_loss.item():.4f}")
#      26 print()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/eval_frame.py:655, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     652 _maybe_set_eval_frame(_callback_from_stance(callback))
#     654 try:
# --> 655     return fn(*args, **kwargs)
#     656 except Unsupported as e:
#     657     if config.verbose:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:1432, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1426             return hijacked_callback(
#    1427                 frame, cache_entry, self.hooks, frame_state
#    1428             )
#    1430 with compile_lock, _disable_current_modes():
#    1431     # skip=1: skip this frame
# -> 1432     return self._torchdynamo_orig_callable(
#    1433         frame, cache_entry, self.hooks, frame_state, skip=1
#    1434     )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:1213, in ConvertFrame.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#    1211 counters["frames"]["total"] += 1
#    1212 try:
# -> 1213     result = self._inner_convert(
#    1214         frame, cache_entry, hooks, frame_state, skip=skip + 1
#    1215     )
#    1216     counters["frames"]["ok"] += 1
#    1217     return result
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:598, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     595     dynamo_tls.traced_frame_infos.append(info)
#     597 with compile_context(CompileContext(compile_id)):
# --> 598     return _compile(
#     599         frame.f_code,
#     600         frame.f_globals,
#     601         frame.f_locals,
#     602         frame.f_builtins,
#     603         frame.closure,
#     604         self._torchdynamo_orig_callable,
#     605         self._one_graph,
#     606         self._export,
#     607         self._export_constraints,
#     608         hooks,
#     609         cache_entry,
#     610         cache_size,
#     611         frame,
#     612         frame_state=frame_state,
#     613         compile_id=compile_id,
#     614         skip=skip + 1,
#     615     )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:1059, in _compile(code, globals, locals, builtins, closure, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#    1057 guarded_code = None
#    1058 try:
# -> 1059     guarded_code = compile_inner(code, one_graph, hooks, transform)
#    1061     # NB: We only put_code_state in success case.  Success case here
#    1062     # does include graph breaks; specifically, if a graph break still
#    1063     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)   1068     # to upload for graph break though, because this can prevent
#    1069     # extra graph break compilations.)
#    1070     put_code_state()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_utils_internal.py:97, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      94 # This is not needed but we have it here to avoid having profile_compile_time
#      95 # in stack traces when profiling is not enabled.
#      96 if not StrobelightCompileTimeProfiler.enabled:
# ---> 97     return function(*args, **kwargs)
#      99 return StrobelightCompileTimeProfiler.profile_compile_time(
#     100     function, phase_name, *args, **kwargs
#     101 )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:761, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     759     stack.enter_context(torch._dynamo.callback_handler.install_callbacks())
#     760     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 761     return _compile_inner(code, one_graph, hooks, transform)
#     763 return (
#     764     ConvertFrameReturn()
#     765 )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:797, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     795 CompileContext.get().attempt = attempt
#     796 try:
# --> 797     out_code = transform_code_object(code, transform)
#     798     break
#     799 except exc.RestartAnalysis as e:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/bytecode_transformation.py:1422, in transform_code_object(code, transformations, safe)
#    1419 instructions = cleaned_instructions(code, safe)
#    1420 propagate_line_nums(instructions)
# -> 1422 transformations(instructions, code_options)
#    1423 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:257, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     255 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     256 try:
# --> 257     return fn(*args, **kwargs)
#     258 finally:
#     259     cleanup.close()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/convert_frame.py:715, in _compile.<locals>.transform(instructions, code_options)
#     713 try:
#     714     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 715         tracer.run()
#     716 except exc.UnspecializeRestartAnalysis:
#     717     speculation_log.clear()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:3498, in InstructionTranslator.run(self)
#    3497 def run(self):
# -> 3498     super().run()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1337, in InstructionTranslatorBase.run(self)
#    1335     self.output.push_tx(self)
#    1336     self.start_point = self.instruction_pointer
# -> 1337     while self.step():
#    1338         pass
#    1339 except TensorifyScalarRestartAnalysis:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1246, in InstructionTranslatorBase.step(self)
#    1243 self.update_block_stack(inst)
#    1245 try:
# -> 1246     self.dispatch_table[inst.opcode](self, inst)
#    1247     return not self.output.should_exit
#    1248 except TensorifyScalarRestartAnalysis:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:819, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     817     return handle_graph_break(self, inst, speculation.reason)
#     818 try:
# --> 819     return inner_fn(self, inst)
#     820 except Unsupported as excp:
#     821     if self.active_generic_context_managers:
#     822         # We don't support graph break under GenericContextWrappingVariable,
#     823         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:2931, in InstructionTranslatorBase.CALL(self, inst)
#    2929 @break_graph_if_unsupported(push=1)
#    2930 def CALL(self, inst):
# -> 2931     self._call(inst)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:2925, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2920     kwargs = {}
#    2922 try:
#    2923     # if call_function fails, need to set kw_names to None, otherwise
#    2924     # a subsequent call may have self.kw_names set to an old value
# -> 2925     self.call_function(fn, args, kwargs)
#    2926 finally:
#    2927     self.kw_names = None
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1170, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1168 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1169     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1170 self.push(fn.call_function(self, args, kwargs))
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/nn_module.py:952, in UnspecializedNNModuleVariable.call_function(self, tx, args, kwargs)
#     944 ctx = (
#     945     record_nn_module_stack(
#     946         str(id(mod)), self.get_nn_module_stack_source(), tx, mod
#    (...)    949     else nullcontext()
#     950 )
#     951 with ctx:
# --> 952     return variables.UserFunctionVariable(fn, source=source).call_function(
#     953         tx, [self] + list(args), kwargs
#     954     )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/functions.py:414, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     412         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     413             return super().call_function(tx, args, kwargs)
# --> 414 return super().call_function(tx, args, kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/functions.py:184, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     178 def call_function(
#     179     self,
#     180     tx: "InstructionTranslator",
#     181     args: "list[VariableTracker]",
#     182     kwargs: "dict[str, VariableTracker]",
#     183 ) -> "VariableTracker":
# --> 184     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1187, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#    1185     return self.inline_generator_function(fn, args, kwargs)
#    1186 else:
# -> 1187     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:3724, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3722 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
#    3723     tracer = cls.build_inline_tracer(parent, func, args, kwargs)
# -> 3724     return tracer.inline_call_()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:3903, in InliningInstructionTranslator.inline_call_(self)
#    3901 try:
#    3902     with strict_ctx:
# -> 3903         self.run()
#    3904 except exc.ObservedException as e:
#    3905     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1337, in InstructionTranslatorBase.run(self)
#    1335     self.output.push_tx(self)
#    1336     self.start_point = self.instruction_pointer
# -> 1337     while self.step():
#    1338         pass
#    1339 except TensorifyScalarRestartAnalysis:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1246, in InstructionTranslatorBase.step(self)
#    1243 self.update_block_stack(inst)
#    1245 try:
# -> 1246     self.dispatch_table[inst.opcode](self, inst)
#    1247     return not self.output.should_exit
#    1248 except TensorifyScalarRestartAnalysis:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:819, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     817     return handle_graph_break(self, inst, speculation.reason)
#     818 try:
# --> 819     return inner_fn(self, inst)
#     820 except Unsupported as excp:
#     821     if self.active_generic_context_managers:
#     822         # We don't support graph break under GenericContextWrappingVariable,
#     823         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:2931, in InstructionTranslatorBase.CALL(self, inst)
#    2929 @break_graph_if_unsupported(push=1)
#    2930 def CALL(self, inst):
# -> 2931     self._call(inst)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:2925, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2920     kwargs = {}
#    2922 try:
#    2923     # if call_function fails, need to set kw_names to None, otherwise
#    2924     # a subsequent call may have self.kw_names set to an old value
# -> 2925     self.call_function(fn, args, kwargs)
#    2926 finally:
#    2927     self.kw_names = None
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1170, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1168 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1169     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1170 self.push(fn.call_function(self, args, kwargs))
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/lazy.py:201, in _create_realize_and_forward.<locals>.realize_and_forward(self, *args, **kwargs)
#     197 @functools.wraps(getattr(VariableTracker, name))
#     198 def realize_and_forward(
#     199     self: LazyVariableTracker, *args: Any, **kwargs: Any
#     200 ) -> Any:
# --> 201     return getattr(self.realize(), name)(*args, **kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/nn_module.py:952, in UnspecializedNNModuleVariable.call_function(self, tx, args, kwargs)
#     944 ctx = (
#     945     record_nn_module_stack(
#     946         str(id(mod)), self.get_nn_module_stack_source(), tx, mod
#    (...)    949     else nullcontext()
#     950 )
#     951 with ctx:
# --> 952     return variables.UserFunctionVariable(fn, source=source).call_function(
#     953         tx, [self] + list(args), kwargs
#     954     )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/functions.py:414, in UserFunctionVariable.call_function(self, tx, args, kwargs)
#     412         with torch._dynamo.side_effects.allow_side_effects_under_checkpoint(tx):
#     413             return super().call_function(tx, args, kwargs)
# --> 414 return super().call_function(tx, args, kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/functions.py:184, in BaseUserFunctionVariable.call_function(self, tx, args, kwargs)
#     178 def call_function(
#     179     self,
#     180     tx: "InstructionTranslator",
#     181     args: "list[VariableTracker]",
#     182     kwargs: "dict[str, VariableTracker]",
#     183 ) -> "VariableTracker":
# --> 184     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1187, in InstructionTranslatorBase.inline_user_function_return(self, fn, args, kwargs)
#    1185     return self.inline_generator_function(fn, args, kwargs)
#    1186 else:
# -> 1187     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:3724, in InliningInstructionTranslator.inline_call(cls, parent, func, args, kwargs)
#    3722 with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
#    3723     tracer = cls.build_inline_tracer(parent, func, args, kwargs)
# -> 3724     return tracer.inline_call_()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:3903, in InliningInstructionTranslator.inline_call_(self)
#    3901 try:
#    3902     with strict_ctx:
# -> 3903         self.run()
#    3904 except exc.ObservedException as e:
#    3905     msg = f"Observed exception DURING INLING {code} : {e}"
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1337, in InstructionTranslatorBase.run(self)
#    1335     self.output.push_tx(self)
#    1336     self.start_point = self.instruction_pointer
# -> 1337     while self.step():
#    1338         pass
#    1339 except TensorifyScalarRestartAnalysis:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1246, in InstructionTranslatorBase.step(self)
#    1243 self.update_block_stack(inst)
#    1245 try:
# -> 1246     self.dispatch_table[inst.opcode](self, inst)
#    1247     return not self.output.should_exit
#    1248 except TensorifyScalarRestartAnalysis:
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:819, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     817     return handle_graph_break(self, inst, speculation.reason)
#     818 try:
# --> 819     return inner_fn(self, inst)
#     820 except Unsupported as excp:
#     821     if self.active_generic_context_managers:
#     822         # We don't support graph break under GenericContextWrappingVariable,
#     823         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:2931, in InstructionTranslatorBase.CALL(self, inst)
#    2929 @break_graph_if_unsupported(push=1)
#    2930 def CALL(self, inst):
# -> 2931     self._call(inst)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:2925, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2920     kwargs = {}
#    2922 try:
#    2923     # if call_function fails, need to set kw_names to None, otherwise
#    2924     # a subsequent call may have self.kw_names set to an old value
# -> 2925     self.call_function(fn, args, kwargs)
#    2926 finally:
#    2927     self.kw_names = None
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:1170, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#    1168 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#    1169     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# -> 1170 self.push(fn.call_function(self, args, kwargs))
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/misc.py:913, in GetAttrVariable.call_function(self, tx, args, kwargs)
#     907 def call_function(
#     908     self,
#     909     tx: "InstructionTranslator",
#     910     args: "list[VariableTracker]",
#     911     kwargs: "dict[str, VariableTracker]",
#     912 ) -> "VariableTracker":
# --> 913     return self.obj.call_method(tx, self.name, args, kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/tensor.py:632, in TensorVariable.call_method(self, tx, name, args, kwargs)
#     628         unimplemented(f"unhandled args for {name}: {e}")
#     630 from .builder import wrap_fx_proxy
# --> 632 return wrap_fx_proxy(
#     633     tx,
#     634     tx.output.create_proxy(
#     635         "call_method",
#     636         name,
#     637         *proxy_args_kwargs([self, *args], kwargs),
#     638     ),
#     639 )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/builder.py:2302, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    2294 kwargs = {
#    2295     "tx": tx,
#    2296     "proxy": proxy,
#    (...)   2299     **options,
#    2300 }
#    2301 if subclass_type is None:
# -> 2302     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    2303 else:
#    2304     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/builder.py:2368, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2364 def wrap_fx_proxy_cls(
#    2365     target_cls, tx, proxy, example_value=None, subclass_type=None, **options
#    2366 ):
#    2367     if example_value is None:
# -> 2368         return _wrap_fx_proxy(
#    2369             target_cls, tx, proxy, example_value, subclass_type, **options
#    2370         )
#    2371     elif isinstance(example_value, torch.Tensor):
#    2372         return _wrap_fx_preexisting_tensor(
#    2373             target_cls, tx, proxy, example_value, subclass_type, **options
#    2374         )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/variables/builder.py:2464, in _wrap_fx_proxy(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2459 # See NOTE: [Deferring tensor pack/unpack hooks until runtime]
#    2460 with torch._dynamo.utils._disable_saved_tensors_hooks_during_tracing():
#    2461     # with preserve_rng_state():
#    2462     # only allow_non_graph_fake in this instance because we handle the non-fake
#    2463     # cases properly below.
# -> 2464     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    2466 return handle_traced_output(
#    2467     example_value, tx, proxy, options, subclass_type, target_cls
#    2468 )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/utils.py:3229, in get_fake_value(node, tx, allow_non_graph_fake)
#    3221     elif isinstance(cause, TypeError) and "argument" in str(cause):
#    3222         unimplemented_v2(
#    3223             gb_type="TypeError when making fake tensor call",
#    3224             context=f"TypeError {node.target}: {cause}",
#    3225             explanation="",
#    3226             hints=[],
#    3227         )
# -> 3229     raise TorchRuntimeError(str(e)).with_traceback(e.__traceback__) from None
#    3231 if not allow_non_graph_fake:
#    3232     _ = pytree.tree_map_only(
#    3233         torch.Tensor, functools.partial(ensure_graph_fake, tx=tx), ret_val
#    3234     )
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/utils.py:3127, in get_fake_value(node, tx, allow_non_graph_fake)
#    3125 try:
#    3126     with tx.fake_mode, enable_python_dispatcher():
# -> 3127         ret_val = wrap_fake_exception(
#    3128             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    3129         )
#    3130 except Unsupported:
#    3131     raise
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/utils.py:2641, in wrap_fake_exception(fn)
#    2639 def wrap_fake_exception(fn):
#    2640     try:
# -> 2641         return fn()
#    2642     except UnsupportedFakeTensorException as e:
#    2643         from .exc import unimplemented_v2
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/utils.py:3128, in get_fake_value.<locals>.<lambda>()
#    3125 try:
#    3126     with tx.fake_mode, enable_python_dispatcher():
#    3127         ret_val = wrap_fake_exception(
# -> 3128             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    3129         )
#    3130 except Unsupported:
#    3131     raise
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/utils.py:3325, in run_node(tracer, node, args, kwargs, nnmodule)
#    3323         raise
#    3324     except Exception as e:
# -> 3325         raise RuntimeError(make_error_message(e)).with_traceback(
#    3326             e.__traceback__
#    3327         ) from e
#    3329 raise AssertionError(op)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_dynamo/utils.py:3295, in run_node(tracer, node, args, kwargs, nnmodule)
#    3287         from .exc import unimplemented_v2
#    3289         unimplemented_v2(
#    3290             gb_type="Missing attribute when running call_method node",
#    3291             context="",
#    3292             explanation=make_error_message("attribute not defined"),
#    3293             hints=[],
#    3294         )
# -> 3295     return getattr(args[0], node.target)(*args[1:], **kwargs)
#    3296 elif op == "call_module":
#    3297     assert nnmodule is not None
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/utils/_stats.py:27, in count.<locals>.wrapper(*args, **kwargs)
#      25     simple_call_counter[fn.__qualname__] = 0
#      26 simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 27 return fn(*args, **kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_subclasses/fake_tensor.py:1282, in FakeTensorMode.__torch_dispatch__(self, func, types, args, kwargs)
#    1278 assert (
#    1279     torch._C._get_dispatch_mode(torch._C._TorchDispatchModeKey.FAKE) is None
#    1280 ), func
#    1281 try:
# -> 1282     return self.dispatch(func, types, args, kwargs)
#    1283 except TypeError:
#    1284     log.exception("fake tensor raised TypeError")
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_subclasses/fake_tensor.py:1823, in FakeTensorMode.dispatch(self, func, types, args, kwargs)
#    1820         return func(*args, **kwargs)
#    1822 if self.cache_enabled:
# -> 1823     return self._cached_dispatch_impl(func, types, args, kwargs)
#    1824 else:
#    1825     return self._dispatch_impl(func, types, args, kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_subclasses/fake_tensor.py:1384, in FakeTensorMode._cached_dispatch_impl(self, func, types, args, kwargs)
#    1382 else:
#    1383     self._validate_cache_key(func, args, kwargs)
# -> 1384     output = self._dispatch_impl(func, types, args, kwargs)
#    1385     entry = self._make_cache_entry(state, key, func, args, kwargs, output)
#    1386     key.strip_shape_env()
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_subclasses/fake_tensor.py:2427, in FakeTensorMode._dispatch_impl(self, func, types, args, kwargs)
#    2425 try:
#    2426     with in_kernel_invocation_manager(self):
# -> 2427         r = func(*args, **kwargs)
#    2428 except NotImplementedError as not_implemented_error:
#    2429     return maybe_run_unsafe_fallback(not_implemented_error)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_ops.py:756, in OpOverload.__call__(self, *args, **kwargs)
#     755 def __call__(self, /, *args, **kwargs):
# --> 756     return self._op(*args, **kwargs)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_refs/__init__.py:4671, in view(a, *shape)
#    4669 @register_decomposition(aten.view.default)
#    4670 def view(a: TensorLikeType, *shape: ShapeType) -> TensorLikeType:
# -> 4671     return _reshape_view_helper(a, *shape, allow_copy=False)
#
# File ~/code/ml/.venv/lib64/python3.13/site-packages/torch/_refs/__init__.py:3800, in _reshape_view_helper(a, allow_copy, *shape)
#    3797             return prims.reshape(a, shape)
#    3799         msg = f"Cannot view a tensor with shape {a.shape} and strides {a.stride()} as a tensor with shape {shape}!"
# -> 3800         raise ValueError(msg)
#    3802     a_ = flatten(a_, idx, end)
#    3804 # Splits the (possibly flattened) dimension to create the desired dim length
#
# TorchRuntimeError: Dynamo failed to run FX node with fake tensors: call_method view(*(FakeTensor(..., size=(8, 128, 4, 16)), 8, 128, 64), **{}): got ValueError('Cannot view a tensor with shape torch.Size([8, 128, 4, 16]) and strides (8192, 16, 2048, 1) as a tensor with shape (8, 128, 64)!')
#
# from user code:
#    File "/tmp/ipykernel_13957/2311210325.py", line 19, in forward
#     x = block(x)
#   File "/tmp/ipykernel_13957/168379530.py", line 10, in forward
#     x = x + self.ln_1(self.mha(x))
#   File "/tmp/ipykernel_13957/3830721539.py", line 22, in forward
#     y = y.transpose(1, 2).view(B, T, C)
#
# Set TORCHDYNAMO_VERBOSE=1 for the internal stack trace (please do this especially if you're reporting a bug to PyTorch). For even more developer context, set TORCH_LOGS="+dynamo"

# %%
import os
os.getcwd()
# Out:
# '/home/lurix/code/ml/projects/nanogpt-self'

# %%
from typing import List


class BPETokenizer:
    def __init__(self):
        self.itos = {}
        self.stoi = {}
        self.vocab_size = 0
        self.max_key = 0
        self.merges = {}
    
    def train(self, text_corpus: str, vocab_size: int):
        """
        Takes in the corpus of text to train on and the vocabulary size.
        
        Input: 
            text_corpus: str - The corpus of text to train the tokenizer on.

            vocab_size: int - The size of the vocabulary of the tokenizer.
        """
        self.vocab_size = vocab_size
        text_corpus_set = set(text_corpus)
        text_corpus_unique = sorted(text_corpus_set)

        assert len(text_corpus_unique) <= vocab_size, f"vocab_size ({vocab_size}) must be greater than or equal to the number of unique chars ({len(text_corpus_unique)}) in the text corpus"

        for ch in text_corpus_unique:
            self.stoi[ch] = self.max_key
            self.itos[self.max_key] = ch
            self.max_key += 1

        text_idx = [self.stoi[ch] for ch in text_corpus]

        while self.max_key < vocab_size:
            pair_count = {}
            for i1, i2 in zip(text_idx, text_idx[1:]):
                pair_count[(i1, i2)] = pair_count.get((i1, i2), 0) + 1

            max_pair = max(pair_count, key=lambda pair: pair_count[pair])
            new_text_idx = []

            i = 0
            while i < len(text_idx)-1:
                if (text_idx[i], text_idx[i+1]) == max_pair:
                    new_text_idx.append(self.max_key)
                    i += 2
                else:
                    new_text_idx.append(text_idx[i])
                    i += 1
            
            merged_pair = self.itos[max_pair[0]] + self.itos[max_pair[1]]
            self.itos[self.max_key] = merged_pair
            self.stoi[merged_pair] = self.max_key

            self.merges[max_pair] = self.max_key
            self.max_key += 1
            text_idx = new_text_idx

        self.final_vocab = sorted(self.stoi.items(), key=lambda item: len(item[0]), reverse=True)
        print("Tokenizer successfully trained!")
        return
    
    def encode(self, text: str):
        """
        Function to encode a given string.

        Input:
            text: str - The text (string) which is to be encoded.
        """
        encoded_idx = []
        rem_text = text

        while rem_text:
            print(f"rem_text: {rem_text}")
            for substr, subkey in self.final_vocab:
                if rem_text.startswith(substr):
                    encoded_idx.append(subkey)
                    rem_text = rem_text[len(substr):]
                    break
        
        return encoded_idx

    def decode(self, idx: List[int]):
        """
        Function to decode a given list of encoded indices.

        Input:
            idx: List[int] - The list of encoded indices (encoding) which is to be decoded.
        """
        return "".join(self.itos[i] for i in idx)

# %%
enc = BPETokenizer()
enc.train("abab", 3)

enc.final_vocab
# Out:
# Tokenizer successfully trained!
# [('ab', 2), ('a', 0), ('b', 1)]

# %%
enc.encode("ababc")
# Out:
# rem_text: ababc
# rem_text: abc
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# ...
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# rem_text: c
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 enc.encode("ababc")
#
# Cell In[6], line 74, in BPETokenizer.encode(self, text)
#      71 rem_text = text
#      73 while rem_text:
# ---> 74     print(f"rem_text: {rem_text}")
#      75     for substr, subkey in self.final_vocab:
#      76         if rem_text.startswith(substr):
#
# KeyboardInterrupt:
